# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from matplotlib import pyplot as plt
import matplotlib
plt.rcParams['figure.figsize'] = (15,10)
import pandas as pd
import numpy as np
pd.set_option('display.max_colwidth',150)
import sys,os
import json
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sample_data = pd.Series(np.random.randint(0,23,100))

# %%
sample_data.head(20)
# Out:
# 0     13
# 1     10
# 2      3
# 3     12
# 4      2
# 5     19
# 6     13
# 7     22
# 8     21
# 9     20
# 10     1
# 11    14
# 12    17
# 13    22
# 14     8
# 15     6
# 16    12
# 17    17
# 18     4
# 19    15
# dtype: int64

# %%
sample_data.plot()

# %%
sample_data.describe()
# Out:
# count    100.000000
# mean      11.700000
# std        6.896786
# min        0.000000
# 25%        6.000000
# 50%       12.500000
# 75%       18.000000
# max       22.000000
# dtype: float64

# %%
sample_data.plot.box()

# %%
sample_data.value_counts()
# Out:
# 19    9
# 2     8
# 17    7
# 13    6
# 12    6
# 7     6
# 22    5
# 20    5
# 1     5
# 21    5
# 8     4
# 3     4
# 4     4
# 10    4
# 15    4
# 16    4
# 9     3
# 6     3
# 14    3
# 18    2
# 0     2
# 5     1
# dtype: int64

# %%
sample_data.value_counts().sort_index().plot.bar()
